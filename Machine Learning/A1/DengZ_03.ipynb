# %% [markdown]
# ## Student: Deng, Zixuan (V00971633)
# # Problem 3 Pruning the tree  [20 points, bonus for both sections]

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(1337)
random.seed(1337)

# Plotting support
from matplotlib import pyplot as plt
from plotnine import *
# Standard libraries
import pandas as pd
import sklearn as sk

# %% [markdown]
# ## 1. Implement a pre-pruning strategy that prevents a tree from exceeding a depth of δ.
# Each leaf node that covers conflicting labels
# will predict the most likely label. What happens with the training and test error for δ ∈ {3, 5, 7}?
# Plot the differences. Use the same evaluation data as in Problem 2.

# %%
original_data = pd.read_csv('elections_clean.csv')
df = pd.read_csv('elections_clean.csv')

# %% [markdown]
# ## 2. [Extra Boundary; 20 points]
# Implement reduced error pruning on your tree. This time, use 50% of the original set (elections clean.csv) for training, 25% for pruning decisions, and the remaining 25% for the final validation.
